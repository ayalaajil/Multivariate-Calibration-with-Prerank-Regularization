# %%
from probmetrics.metrics import Metrics, MetricType
Metrics.get_available_names(metric_type=MetricType.CLASS)
# Out:
# ['class-error',
#  'accuracy',
#  'logloss',
#  'brier',
#  'logloss-clip1e-06',
#  'auroc-ovr',
#  'auroc-ovo-sklearn',
#  'auroc-ovr-sklearn',
#  '1-auroc-ovr',
#  'ece-15',
#  'rmsce-15',
#  'mce-15',
#  'smece',
#  'mpn_logloss-clip1e-06',
#  'mpn_logloss',
#  'mpn_brier',
#  'mpn_class-error',
#  'mpn_accuracy',
#  'calib-err_logloss_ts-mix_cv-5',
#  'calib-err_brier_ts-mix_cv-5',
#  'calib-err_logloss-clip1e-06_ts-mix_cv-5',
#  'refinement_logloss_ts-mix_cv-5',
#  'refinement_brier_ts-mix_cv-5',
#  'refinement_logloss-clip1e-06_ts-mix_cv-5',
#  'calib-err_logloss_isotonic-mix_cv-5',
#  'calib-err_brier_isotonic-mix_cv-5',
#  'calib-err_logloss-clip1e-06_isotonic-mix_cv-5',
#  'refinement_logloss_isotonic-mix_cv-5',
#  'refinement_brier_isotonic-mix_cv-5',
#  'refinement_logloss-clip1e-06_isotonic-mix_cv-5',
#  'calib-err_logloss_ts-mix_all',
#  'calib-err_brier_ts-mix_all',
#  'calib-err_logloss-clip1e-06_ts-mix_all',
#  'refinement_logloss_ts-mix_all',
#  'refinement_brier_ts-mix_all',
#  'refinement_logloss-clip1e-06_ts-mix_all',
#  'calib-err_logloss_isotonic-mix_all',
#  'calib-err_brier_isotonic-mix_all',
#  'calib-err_logloss-clip1e-06_isotonic-mix_all',
#  'refinement_logloss_isotonic-mix_all',
#  'refinement_brier_isotonic-mix_all',
#  'refinement_logloss-clip1e-06_isotonic-mix_all']
